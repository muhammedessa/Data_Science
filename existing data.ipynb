# %%
import numpy as np

# %%
mylist = [22,33,44,55,66,77,88,99]

# %%
print(mylist)
# Out:
# [22, 33, 44, 55, 66, 77, 88, 99]

# %%
myarray = np.asarray(mylist)

# %%
print(myarray)
# Out:
# [22 33 44 55 66 77 88 99]

# %%
print(type(myarray))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(mylist))
# Out:
# <class 'list'>

# %%
mytuple = (22,33,44,55,66,77,88,99)

# %%
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
print( mytuple )
# Out:
# (22, 33, 44, 55, 66, 77, 88, 99)

# %%
myarray_from_tuple = np.asarray(mytuple)

# %%
print(type(myarray_from_tuple))
# Out:
# <class 'numpy.ndarray'>

# %%
mylist2 = [ [22,33,44,55,66,77,88,99] , [1,2,3,4] ]

# %%
print( mylist2 )
# Out:
# [[22, 33, 44, 55, 66, 77, 88, 99], [1, 2, 3, 4]]

# %%
print(type(mylist2))
# Out:
# <class 'list'>

# %%
myarray_from_list = np.asarray(mylist2)

# %%
print( myarray_from_list )
# Out:
# [list([22, 33, 44, 55, 66, 77, 88, 99]) list([1, 2, 3, 4])]

# %%
print(type(myarray_from_list))
# Out:
# <class 'numpy.ndarray'>

# %%
mystring = b"Muhammed Essa Hameed"

# %%
print(type(mystring))
# Out:
# <class 'bytes'>

# %%
mystring_array = np.frombuffer(mystring ,dtype = "S1" )

# %%
print(type(mystring_array))
# Out:
# <class 'numpy.ndarray'>

# %%
print( mystring_array )
# Out:
# [b'M' b'u' b'h' b'a' b'm' b'm' b'e' b'd' b' ' b'E' b's' b's' b'a' b' '
#  b'H' b'a' b'm' b'e' b'e' b'd']
